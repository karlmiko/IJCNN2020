# %% [markdown]
# ## Coverting Mel Spectogram back to Audio Signal and calculating SNR
# - 19/08/2019
# - By Karl Michel Koerich

# %%
#Imports

import librosa
import math
import librosa.display
import IPython.display
import numpy as np
import os

# %%
nb_classes = 10
sr = 22050
frame_size = 110250

# %%
#Indicate folds
train_fold = [1, 2]
test_fold = [3]

# %%
# Put all filenames into a list

test_filename_list  = []
base_path = "gtzan_3f_Win_110250_75/"

j  = 0 
ii = 0
for ii in test_fold:

    path = base_path+"fold"+str(ii)

    for path, subdirs, files in os.walk( path ):
        for name in files:
            test_filename_list.append( os.path.join(path, name) )
            j += 1
    print("Test files processed: "+"fold"+str(ii)+" "+str(j) )
# Out:
# Test files processed: fold3 6929

# %%
# Load 5 second Original Mel Spec

X_valid         = np.load( "folds_mf/2_GTzan_Xs_test_fold"+str(test_fold[0])+"_110250_75_frozen.npy")
X_sample = X_valid[9:10]  #Arbitrary value

# %%
X_sample = np.squeeze(X_sample)
print(X_sample.shape)

len_X = X_valid.shape[0]
print(len_X)
# Out:
# (64, 431)
# 6929

# %%
#Load MF spectrogram wave paths

mf_list  = []
base_path = "gtzan_reconstruct/mf/"

j  = 0 
ii = 0
for ii in test_fold:

    path = base_path+"fold"+str(ii)

    for path, subdirs, files in os.walk( path ):
        for name in files:
            mf_list.append(os.path.join(path, name))
            j += 1
    print("Reconstructed waves processed: "+"fold "+str(ii)+" - "+str(j) )
# Out:
# Reconstructed waves processed: fold 3 - 6929

# %%
#Load MF BIM spectrogram wave paths

mf_bim_list  = []
base_path = "gtzan_reconstruct/mf_BIM/"

j  = 0 
ii = 0
for ii in test_fold:

    path = base_path+"fold"+str(ii)

    for path, subdirs, files in os.walk( path ):
        for name in files:
            mf_bim_list.append(os.path.join(path, name))
            j += 1
    print("Reconstructed waves processed: "+"fold "+str(ii)+" - "+str(j) )
# Out:
# Reconstructed waves processed: fold 3 - 6929

# %%
#Load MF FGSM spectrogram wave paths

mf_fgsm_list  = []
base_path = "gtzan_reconstruct/mf_FGSM/"

j  = 0 
ii = 0
for ii in test_fold:

    path = base_path+"fold"+str(ii)

    for path, subdirs, files in os.walk( path ):
        for name in files:
            mf_fgsm_list.append(os.path.join(path, name))
            j += 1
    print("Reconstructed waves processed: "+"fold "+str(ii)+" - "+str(j) )
# Out:
# Reconstructed waves processed: fold 3 - 6929

# %%
#Power function

def power(v):
    n = 0
    s = 0
    for vn in v:
        square = vn*vn
        s += square
        n += 1
    return math.sqrt(s/n)

# %%
#Reconstructing original mel and attacked mel specs

snr_wave_mf   = np.ones((len_X, 1), dtype=float)
snr_mf_bim    = np.ones((len_X, 1), dtype=float)
snr_mf_fgsm   = np.ones((len_X, 1), dtype=float)
snr_wave_bim  = np.ones((len_X, 1), dtype=float)
snr_wave_fgsm = np.ones((len_X, 1), dtype=float)

for i in range(0, len_X):
    
    #POWER ORIGINAL
    file_wave, sr = librosa.load(test_filename_list[i])
    power_wave = power(file_wave[:110080])
        
    #POWER MF
    audio_rec_mf, sr = librosa.load(mf_list[i])
    power_mf = power(audio_rec_mf)
    
    #POWER MF_BIM
    audio_rec_bim, sr = librosa.load(mf_bim_list[i])
    power_mf_bim = power(audio_rec_bim)
    
    #POWER MF_FGSM
    audio_rec_fgsm, sr = librosa.load(mf_fgsm_list[i])
    power_mf_fgsm = power(audio_rec_fgsm)
    
    #POWER NOISE ORIGINAL-MF
    power_wave_m_mf = abs(power_wave-power_mf)
    quo = power_wave/power_wave_m_mf    
    snr = 20*math.log(quo, 10)
    snr_wave_mf[i] = snr
    
    #POWER NOISE MF-BIM
    power_mf_m_bim = abs(power_mf-power_mf_bim)
    quo = power_mf/power_mf_m_bim    
    snr = 20*math.log(quo, 10)
    snr_mf_bim[i] = snr
    
    #POWER NOISE MF-FGSM
    power_mf_m_fgsm = abs(power_mf-power_mf_fgsm)
    quo = power_mf/power_mf_m_fgsm   
    snr = 20*math.log(quo, 10)
    snr_mf_fgsm[i] = snr
    
    #POWER NOISE ORIGINAL-BIM
    power_wave_m_bim = abs(power_wave-power_mf_bim)
    quo = power_wave/power_wave_m_bim    
    snr = 20*math.log(quo, 10)
    snr_wave_bim[i] = snr
    
    #POWER NOISE ORIGINAL-FGSM
    power_wave_m_fgsm = abs(power_wave-power_mf_fgsm)
    quo = power_wave/power_wave_m_fgsm   
    snr = 20*math.log(quo, 10)
    snr_wave_fgsm[i] = snr
    
    if (i%50 == 0.000):
        print("Files read: " + str(i) ) 
        print("SNR WAVE-MF:", snr_wave_mf[i])
        print("SNR MF-BIM :", snr_mf_bim[i])
        print("SNR MF-FGSM:", snr_mf_fgsm[i])
        print("SNR WAVE-BIM :", snr_wave_bim[i])
        print("SNR WAVE-FGSM:", snr_wave_fgsm[i])
# Out:
# Files read: 0
# SNR WAVE-MF: [11.84858773]
# SNR MF-BIM : [39.21224621]
# SNR MF-FGSM: [37.45661833]
# SNR WAVE-BIM : [12.13007092]
# SNR WAVE-FGSM: [12.19439351]
# Files read: 50
# SNR WAVE-MF: [35.34789873]
# SNR MF-BIM : [40.74938575]
# SNR MF-FGSM: [39.24684604]
# SNR WAVE-BIM : [41.86476208]
# SNR WAVE-FGSM: [43.92385862]
# Files read: 100
# SNR WAVE-MF: [10.87503057]
# SNR MF-BIM : [55.70334667]
# SNR MF-FGSM: [51.04883435]
# SNR WAVE-BIM : [10.83952831]
# SNR WAVE-FGSM: [10.93603954]
# Files read: 150
# SNR WAVE-MF: [2.85915282]
# SNR MF-BIM : [47.34989578]
# SNR MF-FGSM: [44.09846705]
# SNR WAVE-BIM : [2.94867285]
# SNR WAVE-FGSM: [2.73061286]
# Files read: 200
# SNR WAVE-MF: [9.65110672]
# SNR MF-BIM : [40.97541694]
# SNR MF-FGSM: [35.47548849]
# SNR WAVE-BIM : [9.81076248]
# SNR WAVE-FGSM: [9.95432411]
# Files read: 250
# SNR WAVE-MF: [30.83693234]
# SNR MF-BIM : [43.29957284]
# SNR MF-FGSM: [48.94056565]
# SNR WAVE-BIM : [33.27798167]
# SNR WAVE-FGSM: [32.02632284]
# Files read: 300
# SNR WAVE-MF: [10.98149658]
# SNR MF-BIM : [36.15170005]
# SNR MF-FGSM: [36.37131788]
# SNR WAVE-BIM : [11.33216774]
# SNR WAVE-FGSM: [11.32323782]
# Files read: 350
# SNR WAVE-MF: [1.70271099]
# SNR MF-BIM : [36.96195573]
# SNR MF-FGSM: [37.91189746]
# SNR WAVE-BIM : [1.43377046]
# SNR WAVE-FGSM: [1.4612486]
# Files read: 400
# SNR WAVE-MF: [5.67079426]
# SNR MF-BIM : [43.26306247]
# SNR MF-FGSM: [49.69397756]
# SNR WAVE-BIM : [5.84682733]
# SNR WAVE-FGSM: [5.58807901]
# Files read: 450
# SNR WAVE-MF: [11.38624776]
# SNR MF-BIM : [58.85262322]
# SNR MF-FGSM: [46.28209647]
# SNR WAVE-BIM : [11.41314703]
# SNR WAVE-FGSM: [11.50118608]
# Files read: 500
# SNR WAVE-MF: [7.29246726]
# SNR MF-BIM : [45.88372678]
# SNR MF-FGSM: [45.70596148]
# SNR WAVE-BIM : [7.23462646]
# SNR WAVE-FGSM: [7.35190393]
# Files read: 550
# SNR WAVE-MF: [-0.9436474]
# SNR MF-BIM : [58.7126715]
# SNR MF-FGSM: [47.98096511]
# SNR WAVE-BIM : [-0.92451638]
# SNR WAVE-FGSM: [-1.00914221]
# Files read: 600
# SNR WAVE-MF: [17.11283078]
# SNR MF-BIM : [48.74084422]
# SNR MF-FGSM: [46.76391768]
# SNR WAVE-BIM : [17.31104989]
# SNR WAVE-FGSM: [17.3624461]
# Files read: 650
# SNR WAVE-MF: [8.17424258]
# SNR MF-BIM : [51.51997176]
# SNR MF-FGSM: [65.92760018]
# SNR WAVE-BIM : [8.21035173]
# SNR WAVE-FGSM: [8.18110544]
# Files read: 700
# SNR WAVE-MF: [15.14303742]
# SNR MF-BIM : [57.48736355]
# SNR MF-FGSM: [43.06737022]
# SNR WAVE-BIM : [15.22130154]
# SNR WAVE-FGSM: [15.5628548]
# Files read: 750
# SNR WAVE-MF: [11.44183125]
# SNR MF-BIM : [50.71580726]
# SNR MF-FGSM: [38.66573042]
# SNR WAVE-BIM : [11.37296812]
# SNR WAVE-FGSM: [11.16932108]
# Files read: 800
# SNR WAVE-MF: [5.9937172]
# SNR MF-BIM : [41.69674063]
# SNR MF-FGSM: [42.78021145]
# SNR WAVE-BIM : [5.7824123]
# SNR WAVE-FGSM: [5.80692821]
# Files read: 850
# SNR WAVE-MF: [21.13096776]
# SNR MF-BIM : [39.10290172]
# SNR MF-FGSM: [46.29697157]
# SNR WAVE-BIM : [20.0127947]
# SNR WAVE-FGSM: [20.62474386]
# Files read: 900
# SNR WAVE-MF: [16.7326105]
# SNR MF-BIM : [43.69331756]
# SNR MF-FGSM: [44.10700918]
# SNR WAVE-BIM : [17.19101419]
# SNR WAVE-FGSM: [17.16914801]
# Files read: 950
# SNR WAVE-MF: [19.17752279]
# SNR MF-BIM : [38.56746827]
# SNR MF-FGSM: [35.82622139]
# SNR WAVE-BIM : [20.04918789]
# SNR WAVE-FGSM: [20.39627433]
# Files read: 1000
# SNR WAVE-MF: [27.12111743]
# SNR MF-BIM : [37.46779088]
# SNR MF-FGSM: [39.5884378]
# SNR WAVE-BIM : [30.10170464]
# SNR WAVE-FGSM: [29.36366511]
# Files read: 1050
# SNR WAVE-MF: [15.74391881]
# SNR MF-BIM : [53.17367314]
# SNR MF-FGSM: [73.80786489]
# SNR WAVE-BIM : [15.64675589]
# SNR WAVE-FGSM: [15.7348407]
# Files read: 1100
# SNR WAVE-MF: [11.38789372]
# SNR MF-BIM : [39.85824302]
# SNR MF-FGSM: [34.81555105]
# SNR WAVE-BIM : [11.15185376]
# SNR WAVE-FGSM: [10.97048879]
# Files read: 1150
# SNR WAVE-MF: [9.62336213]
# SNR MF-BIM : [29.41926974]
# SNR MF-FGSM: [30.50997854]
# SNR WAVE-BIM : [10.24034089]
# SNR WAVE-FGSM: [10.16521001]
# Files read: 1200
# SNR WAVE-MF: [6.22026768]
# SNR MF-BIM : [32.75698281]
# SNR MF-FGSM: [34.20185563]
# SNR WAVE-BIM : [5.63147228]
# SNR WAVE-FGSM: [5.71915459]
# Files read: 1250
# SNR WAVE-MF: [6.58446971]
# SNR MF-BIM : [46.70251603]
# SNR MF-FGSM: [52.06297271]
# SNR WAVE-BIM : [6.45953584]
# SNR WAVE-FGSM: [6.51684696]
# Files read: 1300
# SNR WAVE-MF: [12.62145725]
# SNR MF-BIM : [39.70533112]
# SNR MF-FGSM: [79.09285036]
# SNR WAVE-BIM : [12.15983227]
# SNR WAVE-FGSM: [12.61637124]
# Files read: 1350
# SNR WAVE-MF: [77.67600356]
# SNR MF-BIM : [34.54661719]
# SNR MF-FGSM: [35.64508638]
# SNR WAVE-BIM : [34.48511818]
# SNR WAVE-FGSM: [35.57548164]
# Files read: 1400
# SNR WAVE-MF: [-7.90288678]
# SNR MF-BIM : [44.49774942]
# SNR MF-FGSM: [41.59972328]
# SNR WAVE-BIM : [-7.82999535]
# SNR WAVE-FGSM: [-7.80095666]
# Files read: 1450
# SNR WAVE-MF: [5.29727182]
# SNR MF-BIM : [53.35176603]
# SNR MF-FGSM: [40.65617434]
# SNR WAVE-BIM : [5.24439669]
# SNR WAVE-FGSM: [5.07148598]
# Files read: 1500
# SNR WAVE-MF: [-4.24985397]
# SNR MF-BIM : [55.96496166]
# SNR MF-FGSM: [42.95558072]
# SNR WAVE-BIM : [-4.27212097]
# SNR WAVE-FGSM: [-4.34898436]
# Files read: 1550
# SNR WAVE-MF: [14.19987699]
# SNR MF-BIM : [58.39707114]
# SNR MF-FGSM: [43.44135787]
# SNR WAVE-BIM : [14.1568559]
# SNR WAVE-FGSM: [13.96187564]
# Files read: 1600
# SNR WAVE-MF: [35.40203849]
# SNR MF-BIM : [48.11672485]
# SNR MF-FGSM: [36.6949555]
# SNR WAVE-BIM : [33.62217434]
# SNR WAVE-FGSM: [30.07239079]
# Files read: 1650
# SNR WAVE-MF: [-3.88260284]
# SNR MF-BIM : [42.39274421]
# SNR MF-FGSM: [36.91386965]
# SNR WAVE-BIM : [-3.99005395]
# SNR WAVE-FGSM: [-4.08342583]
# Files read: 1700
# SNR WAVE-MF: [-2.01025383]
# SNR MF-BIM : [37.38395155]
# SNR MF-FGSM: [51.79483424]
# SNR WAVE-BIM : [-1.79714146]
# SNR WAVE-FGSM: [-2.0502251]
# Files read: 1750
# SNR WAVE-MF: [-3.73510424]
# SNR MF-BIM : [59.30723022]
# SNR MF-FGSM: [65.13504057]
# SNR WAVE-BIM : [-3.71956407]
# SNR WAVE-FGSM: [-3.74303799]
# Files read: 1800
# SNR WAVE-MF: [0.51980494]
# SNR MF-BIM : [84.69039354]
# SNR MF-FGSM: [45.20339139]
# SNR WAVE-BIM : [0.52084856]
# SNR WAVE-FGSM: [0.61873658]
# Files read: 1850
# SNR WAVE-MF: [-8.75711685]
# SNR MF-BIM : [64.6763421]
# SNR MF-FGSM: [58.80258013]
# SNR WAVE-BIM : [-8.75019435]
# SNR WAVE-FGSM: [-8.7707137]
# Files read: 1900
# SNR WAVE-MF: [-0.29314198]
# SNR MF-BIM : [33.23559425]
# SNR MF-FGSM: [33.49221456]
# SNR WAVE-BIM : [-0.6576058]
# SNR WAVE-FGSM: [-0.64720871]
# Files read: 1950
# SNR WAVE-MF: [3.76777112]
# SNR MF-BIM : [50.18813839]
# SNR MF-FGSM: [47.26560851]
# SNR WAVE-BIM : [3.83639606]
# SNR WAVE-FGSM: [3.86399822]
# Files read: 2000
# SNR WAVE-MF: [4.94522873]
# SNR MF-BIM : [48.30720389]
# SNR MF-FGSM: [71.68439914]
# SNR WAVE-BIM : [4.85335733]
# SNR WAVE-FGSM: [4.93897034]
# Files read: 2050
# SNR WAVE-MF: [25.06292428]
# SNR MF-BIM : [35.27646497]
# SNR MF-FGSM: [36.91368109]
# SNR WAVE-BIM : [22.61353525]
# SNR WAVE-FGSM: [22.98816054]
# Files read: 2100
# SNR WAVE-MF: [5.56648627]
# SNR MF-BIM : [39.44257464]
# SNR MF-FGSM: [38.5414878]
# SNR WAVE-BIM : [5.65006758]
# SNR WAVE-FGSM: [5.65925311]
# Files read: 2150
# SNR WAVE-MF: [14.1962996]
# SNR MF-BIM : [37.89565636]
# SNR MF-FGSM: [42.20608385]
# SNR WAVE-BIM : [14.66541646]
# SNR WAVE-FGSM: [14.47887197]
# Files read: 2200
# SNR WAVE-MF: [9.8642998]
# SNR MF-BIM : [44.4379463]
# SNR MF-FGSM: [43.54565909]
# SNR WAVE-BIM : [9.65256187]
# SNR WAVE-FGSM: [9.62996027]
# Files read: 2250
# SNR WAVE-MF: [16.18019287]
# SNR MF-BIM : [46.38775147]
# SNR MF-FGSM: [46.35751837]
# SNR WAVE-BIM : [16.4097541]
# SNR WAVE-FGSM: [16.41056524]
# Files read: 2300
# SNR WAVE-MF: [-1.09294531]
# SNR MF-BIM : [50.56421002]
# SNR MF-FGSM: [43.77876335]
# SNR WAVE-BIM : [-1.04437366]
# SNR WAVE-FGSM: [-1.1980955]
# Files read: 2350
# SNR WAVE-MF: [14.10949273]
# SNR MF-BIM : [36.68632742]
# SNR MF-FGSM: [39.7278136]
# SNR WAVE-BIM : [14.64401796]
# SNR WAVE-FGSM: [14.48265256]
# Files read: 2400
# SNR WAVE-MF: [14.47341084]
# SNR MF-BIM : [39.44318569]
# SNR MF-FGSM: [46.32369571]
# SNR WAVE-BIM : [15.07663642]
# SNR WAVE-FGSM: [14.74141639]
# Files read: 2450
# SNR WAVE-MF: [-0.49946471]
# SNR MF-BIM : [60.95998843]
# SNR MF-FGSM: [43.2705645]
# SNR WAVE-BIM : [-0.48433202]
# SNR WAVE-FGSM: [-0.61457865]
# Files read: 2500
# SNR WAVE-MF: [9.12104098]
# SNR MF-BIM : [38.90174785]
# SNR MF-FGSM: [48.52903598]
# SNR WAVE-BIM : [9.30612798]
# SNR WAVE-FGSM: [9.18170179]
# Files read: 2550
# SNR WAVE-MF: [10.80086214]
# SNR MF-BIM : [53.19897647]
# SNR MF-FGSM: [39.79617363]
# SNR WAVE-BIM : [10.71636605]
# SNR WAVE-FGSM: [10.41240488]
# Files read: 2600
# SNR WAVE-MF: [3.09732059]
# SNR MF-BIM : [40.08612116]
# SNR MF-FGSM: [40.37629231]
# SNR WAVE-BIM : [3.30872418]
# SNR WAVE-FGSM: [3.30169608]
# Files read: 2650
# SNR WAVE-MF: [15.26798546]
# SNR MF-BIM : [44.50212137]
# SNR MF-FGSM: [40.78807216]
# SNR WAVE-BIM : [15.62702116]
# SNR WAVE-FGSM: [15.82484045]
# Files read: 2700
# SNR WAVE-MF: [5.701724]
# SNR MF-BIM : [38.0396079]
# SNR MF-FGSM: [30.58040881]
# SNR WAVE-BIM : [5.80331986]
# SNR WAVE-FGSM: [5.94345244]
# Files read: 2750
# SNR WAVE-MF: [5.78714396]
# SNR MF-BIM : [35.84036638]
# SNR MF-FGSM: [35.34609359]
# SNR WAVE-BIM : [5.92094786]
# SNR WAVE-FGSM: [5.92884706]
# Files read: 2800
# SNR WAVE-MF: [13.00211428]
# SNR MF-BIM : [60.23599713]
# SNR MF-FGSM: [45.47788447]
# SNR WAVE-BIM : [13.03147845]
# SNR WAVE-FGSM: [13.163933]
# Files read: 2850
# SNR WAVE-MF: [26.0837201]
# SNR MF-BIM : [45.3075554]
# SNR MF-FGSM: [43.0292553]
# SNR WAVE-BIM : [27.03678018]
# SNR WAVE-FGSM: [27.34426773]
# Files read: 2900
# SNR WAVE-MF: [1.33063791]
# SNR MF-BIM : [42.16292455]
# SNR MF-FGSM: [38.67105255]
# SNR WAVE-BIM : [1.18522717]
# SNR WAVE-FGSM: [1.11416313]
# Files read: 2950
# SNR WAVE-MF: [6.6040119]
# SNR MF-BIM : [45.76982521]
# SNR MF-FGSM: [33.99294557]
# SNR WAVE-BIM : [6.65507457]
# SNR WAVE-FGSM: [6.80384055]
# Files read: 3000
# SNR WAVE-MF: [17.09637927]
# SNR MF-BIM : [50.67168397]
# SNR MF-FGSM: [46.03240282]
# SNR WAVE-BIM : [17.25437502]
# SNR WAVE-FGSM: [17.36766696]
# Files read: 3050
# SNR WAVE-MF: [4.44544964]
# SNR MF-BIM : [39.10687463]
# SNR MF-FGSM: [33.66902541]
# SNR WAVE-BIM : [4.51002267]
# SNR WAVE-FGSM: [4.56660867]
# Files read: 3100
# SNR WAVE-MF: [16.07351331]
# SNR MF-BIM : [40.36960398]
# SNR MF-FGSM: [53.86496153]
# SNR WAVE-BIM : [15.48125627]
# SNR WAVE-FGSM: [16.20409835]
# Files read: 3150
# SNR WAVE-MF: [7.94655398]
# SNR MF-BIM : [38.20125847]
# SNR MF-FGSM: [37.37815344]
# SNR WAVE-BIM : [8.10793405]
# SNR WAVE-FGSM: [8.12414008]
# Files read: 3200
# SNR WAVE-MF: [7.03413816]
# SNR MF-BIM : [60.50750594]
# SNR MF-FGSM: [47.00990101]
# SNR WAVE-BIM : [7.04436516]
# SNR WAVE-FGSM: [7.08262058]
# Files read: 3250
# SNR WAVE-MF: [11.1905332]
# SNR MF-BIM : [44.83390655]
# SNR MF-FGSM: [48.20219029]
# SNR WAVE-BIM : [11.06072535]
# SNR WAVE-FGSM: [11.27973304]
# Files read: 3300
# SNR WAVE-MF: [10.30997995]
# SNR MF-BIM : [71.33918467]
# SNR MF-FGSM: [58.71488184]
# SNR WAVE-BIM : [10.31534266]
# SNR WAVE-FGSM: [10.33294353]
# Files read: 3350
# SNR WAVE-MF: [7.25341824]
# SNR MF-BIM : [55.3182099]
# SNR MF-FGSM: [41.30263311]
# SNR WAVE-BIM : [7.23400809]
# SNR WAVE-FGSM: [7.35153513]
# Files read: 3400
# SNR WAVE-MF: [16.85487912]
# SNR MF-BIM : [32.55713628]
# SNR MF-FGSM: [34.29416531]
# SNR WAVE-BIM : [15.36166105]
# SNR WAVE-FGSM: [15.61395689]
# Files read: 3450
# SNR WAVE-MF: [7.68115263]
# SNR MF-BIM : [65.25952282]
# SNR MF-FGSM: [47.58393826]
# SNR WAVE-BIM : [7.67441712]
# SNR WAVE-FGSM: [7.73286695]
# Files read: 3500
# SNR WAVE-MF: [9.82823899]
# SNR MF-BIM : [59.31746635]
# SNR MF-FGSM: [55.96906429]
# SNR WAVE-BIM : [9.84799632]
# SNR WAVE-FGSM: [9.79927021]
# Files read: 3550
# SNR WAVE-MF: [10.47484196]
# SNR MF-BIM : [34.683616]
# SNR MF-FGSM: [38.70543785]
# SNR WAVE-BIM : [10.85800805]
# SNR WAVE-FGSM: [10.71401803]
# Files read: 3600
# SNR WAVE-MF: [17.14482929]
# SNR MF-BIM : [34.12926471]
# SNR MF-FGSM: [35.72237612]
# SNR WAVE-BIM : [16.14613952]
# SNR WAVE-FGSM: [16.3056899]
# Files read: 3650
# SNR WAVE-MF: [9.29827626]
# SNR MF-BIM : [31.39876553]
# SNR MF-FGSM: [29.98844553]
# SNR WAVE-BIM : [9.75844505]
# SNR WAVE-FGSM: [9.84215974]
# Files read: 3700
# SNR WAVE-MF: [14.54302558]
# SNR MF-BIM : [32.70286801]
# SNR MF-FGSM: [31.38528384]
# SNR WAVE-BIM : [15.46233297]
# SNR WAVE-FGSM: [15.6226456]
# Files read: 3750
# SNR WAVE-MF: [3.99097199]
# SNR MF-BIM : [45.39371138]
# SNR MF-FGSM: [37.68128365]
# SNR WAVE-BIM : [4.01824058]
# SNR WAVE-FGSM: [4.05738631]
# Files read: 3800
# SNR WAVE-MF: [9.33694158]
# SNR MF-BIM : [36.32586659]
# SNR MF-FGSM: [35.89219483]
# SNR WAVE-BIM : [9.59667283]
# SNR WAVE-FGSM: [9.61018127]
# Files read: 3850
# SNR WAVE-MF: [7.44251009]
# SNR MF-BIM : [42.69333095]
# SNR MF-FGSM: [63.17885468]
# SNR WAVE-BIM : [7.52930395]
# SNR WAVE-FGSM: [7.4506806]
# Files read: 3900
# SNR WAVE-MF: [4.53876631]
# SNR MF-BIM : [41.08734863]
# SNR MF-FGSM: [48.70464682]
# SNR WAVE-BIM : [4.59152424]
# SNR WAVE-FGSM: [4.51691095]
# Files read: 3950
# SNR WAVE-MF: [11.08373314]
# SNR MF-BIM : [35.3964192]
# SNR MF-FGSM: [32.4120603]
# SNR WAVE-BIM : [10.71076079]
# SNR WAVE-FGSM: [10.56235525]
# Files read: 4000
# SNR WAVE-MF: [8.77685987]
# SNR MF-BIM : [30.13861332]
# SNR MF-FGSM: [34.42576124]
# SNR WAVE-BIM : [9.26241005]
# SNR WAVE-FGSM: [9.07001863]
# Files read: 4050
# SNR WAVE-MF: [8.99009086]
# SNR MF-BIM : [34.11920312]
# SNR MF-FGSM: [37.3646259]
# SNR WAVE-BIM : [9.30606144]
# SNR WAVE-FGSM: [9.20631016]
# Files read: 4100
# SNR WAVE-MF: [7.05625139]
# SNR MF-BIM : [43.00873353]
# SNR MF-FGSM: [68.52368974]
# SNR WAVE-BIM : [7.13358226]
# SNR WAVE-FGSM: [7.05217222]
# Files read: 4150
# SNR WAVE-MF: [15.04537729]
# SNR MF-BIM : [57.98252062]
# SNR MF-FGSM: [38.37927136]
# SNR WAVE-BIM : [15.1185798]
# SNR WAVE-FGSM: [15.77128424]
# Files read: 4200
# SNR WAVE-MF: [-6.98817336]
# SNR MF-BIM : [31.48052644]
# SNR MF-FGSM: [40.23286854]
# SNR WAVE-BIM : [-7.31709706]
# SNR WAVE-FGSM: [-7.10970387]
# Files read: 4250
# SNR WAVE-MF: [-28.70229924]
# SNR MF-BIM : [34.69557927]
# SNR MF-FGSM: [38.70425567]
# SNR WAVE-BIM : [-28.8665785]
# SNR WAVE-FGSM: [-28.80621035]
# Files read: 4300
# SNR WAVE-MF: [-7.31122059]
# SNR MF-BIM : [34.15958218]
# SNR MF-FGSM: [33.09159444]
# SNR WAVE-BIM : [-7.55135048]
# SNR WAVE-FGSM: [-7.58228251]
# Files read: 4350
# SNR WAVE-MF: [-7.2892324]
# SNR MF-BIM : [31.99670464]
# SNR MF-FGSM: [35.84951608]
# SNR WAVE-BIM : [-7.59630366]
# SNR WAVE-FGSM: [-7.48753617]
# Files read: 4400
# SNR WAVE-MF: [-2.39535841]
# SNR MF-BIM : [50.94380218]
# SNR MF-FGSM: [61.41277631]
# SNR WAVE-BIM : [-2.43859034]
# SNR WAVE-FGSM: [-2.40833357]
# Files read: 4450
# SNR WAVE-MF: [-13.60669299]
# SNR MF-BIM : [34.03899113]
# SNR MF-FGSM: [30.14239521]
# SNR WAVE-BIM : [-13.81277764]
# SNR WAVE-FGSM: [-13.92731805]
# Files read: 4500
# SNR WAVE-MF: [8.17757859]
# SNR MF-BIM : [38.53991608]
# SNR MF-FGSM: [36.63482976]
# SNR WAVE-BIM : [7.81887993]
# SNR WAVE-FGSM: [7.73312774]
# Files read: 4550
# SNR WAVE-MF: [-16.81409604]
# SNR MF-BIM : [34.40543967]
# SNR MF-FGSM: [34.54847238]
# SNR WAVE-BIM : [-17.00133511]
# SNR WAVE-FGSM: [-16.99830925]
# Files read: 4600
# SNR WAVE-MF: [-9.48923673]
# SNR MF-BIM : [38.37783435]
# SNR MF-FGSM: [31.98069831]
# SNR WAVE-BIM : [-9.62793012]
# SNR WAVE-FGSM: [-9.77643692]
# Files read: 4650
# SNR WAVE-MF: [-28.53619853]
# SNR MF-BIM : [48.74818069]
# SNR MF-FGSM: [55.42261266]
# SNR WAVE-BIM : [-28.50322335]
# SNR WAVE-FGSM: [-28.52092205]
# Files read: 4700
# SNR WAVE-MF: [-0.63205244]
# SNR MF-BIM : [48.00937488]
# SNR MF-FGSM: [39.89460043]
# SNR WAVE-BIM : [-0.69845739]
# SNR WAVE-FGSM: [-0.80008474]
# Files read: 4750
# SNR WAVE-MF: [-12.64175748]
# SNR MF-BIM : [34.94153596]
# SNR MF-FGSM: [31.48925603]
# SNR WAVE-BIM : [-12.83145198]
# SNR WAVE-FGSM: [-12.92254712]
# Files read: 4800
# SNR WAVE-MF: [-3.39384696]
# SNR MF-BIM : [49.33017562]
# SNR MF-FGSM: [39.26739494]
# SNR WAVE-BIM : [-3.44344729]
# SNR WAVE-FGSM: [-3.55085901]
# Files read: 4850
# SNR WAVE-MF: [-3.73383831]
# SNR MF-BIM : [36.97865074]
# SNR MF-FGSM: [33.62877647]
# SNR WAVE-BIM : [-3.93451397]
# SNR WAVE-FGSM: [-4.02737067]
# Files read: 4900
# SNR WAVE-MF: [13.76165283]
# SNR MF-BIM : [46.05444461]
# SNR MF-FGSM: [41.11639302]
# SNR WAVE-BIM : [13.93097974]
# SNR WAVE-FGSM: [14.06289202]
# Files read: 4950
# SNR WAVE-MF: [37.91443151]
# SNR MF-BIM : [37.74400647]
# SNR MF-FGSM: [38.48968513]
# SNR WAVE-BIM : [31.7526219]
# SNR WAVE-FGSM: [32.12347245]
# Files read: 5000
# SNR WAVE-MF: [19.94508795]
# SNR MF-BIM : [40.47136486]
# SNR MF-FGSM: [39.42334055]
# SNR WAVE-BIM : [19.08891155]
# SNR WAVE-FGSM: [18.98497824]
# Files read: 5050
# SNR WAVE-MF: [4.93489528]
# SNR MF-BIM : [36.40627847]
# SNR MF-FGSM: [34.97346645]
# SNR WAVE-BIM : [4.57904371]
# SNR WAVE-FGSM: [4.51673742]
# Files read: 5100
# SNR WAVE-MF: [10.56972818]
# SNR MF-BIM : [56.86202165]
# SNR MF-FGSM: [49.67426631]
# SNR WAVE-BIM : [10.54015218]
# SNR WAVE-FGSM: [10.63776854]
# Files read: 5150
# SNR WAVE-MF: [14.31825124]
# SNR MF-BIM : [41.73464347]
# SNR MF-FGSM: [38.92554419]
# SNR WAVE-BIM : [13.88812093]
# SNR WAVE-FGSM: [13.72934414]
# Files read: 5200
# SNR WAVE-MF: [9.76669422]
# SNR MF-BIM : [42.27173436]
# SNR MF-FGSM: [47.63353955]
# SNR WAVE-BIM : [9.49816341]
# SNR WAVE-FGSM: [9.91506158]
# Files read: 5250
# SNR WAVE-MF: [7.04865279]
# SNR MF-BIM : [46.36169553]
# SNR MF-FGSM: [42.7453385]
# SNR WAVE-BIM : [7.10106099]
# SNR WAVE-FGSM: [7.12824965]
# Files read: 5300
# SNR WAVE-MF: [7.14723629]
# SNR MF-BIM : [41.80191162]
# SNR MF-FGSM: [56.71249368]
# SNR WAVE-BIM : [7.23784516]
# SNR WAVE-FGSM: [7.13105646]
# Files read: 5350
# SNR WAVE-MF: [21.54520118]
# SNR MF-BIM : [39.61354599]
# SNR MF-FGSM: [36.40680875]
# SNR WAVE-BIM : [22.60094803]
# SNR WAVE-FGSM: [23.11730114]
# Files read: 5400
# SNR WAVE-MF: [5.56600464]
# SNR MF-BIM : [43.08167155]
# SNR MF-FGSM: [41.15498381]
# SNR WAVE-BIM : [5.39123931]
# SNR WAVE-FGSM: [5.34837699]
# Files read: 5450
# SNR WAVE-MF: [8.39966429]
# SNR MF-BIM : [37.30415789]
# SNR MF-FGSM: [60.2745898]
# SNR WAVE-BIM : [8.59496858]
# SNR WAVE-FGSM: [8.41339395]
# Files read: 5500
# SNR WAVE-MF: [16.12914654]
# SNR MF-BIM : [48.61941354]
# SNR MF-FGSM: [42.34921896]
# SNR WAVE-BIM : [16.30491988]
# SNR WAVE-FGSM: [16.49489925]
# Files read: 5550
# SNR WAVE-MF: [18.39351351]
# SNR MF-BIM : [42.26317135]
# SNR MF-FGSM: [48.43845469]
# SNR WAVE-BIM : [18.89723462]
# SNR WAVE-FGSM: [18.63727984]
# Files read: 5600
# SNR WAVE-MF: [0.29256592]
# SNR MF-BIM : [40.55085281]
# SNR MF-FGSM: [36.98179907]
# SNR WAVE-BIM : [0.1282937]
# SNR WAVE-FGSM: [0.04598975]
# Files read: 5650
# SNR WAVE-MF: [9.39468475]
# SNR MF-BIM : [41.84109776]
# SNR MF-FGSM: [44.24151447]
# SNR WAVE-BIM : [9.12150806]
# SNR WAVE-FGSM: [9.18668645]
# Files read: 5700
# SNR WAVE-MF: [9.10671098]
# SNR MF-BIM : [50.70447738]
# SNR MF-FGSM: [45.1755384]
# SNR WAVE-BIM : [9.00966311]
# SNR WAVE-FGSM: [8.92419932]
# Files read: 5750
# SNR WAVE-MF: [15.9039558]
# SNR MF-BIM : [43.5221322]
# SNR MF-FGSM: [44.88375287]
# SNR WAVE-BIM : [15.60570805]
# SNR WAVE-FGSM: [15.64835165]
# Files read: 5800
# SNR WAVE-MF: [27.23094684]
# SNR MF-BIM : [35.81930184]
# SNR MF-FGSM: [40.68352859]
# SNR WAVE-BIM : [24.38180735]
# SNR WAVE-FGSM: [25.49130638]
# Files read: 5850
# SNR WAVE-MF: [8.96989783]
# SNR MF-BIM : [44.13151378]
# SNR MF-FGSM: [41.9948873]
# SNR WAVE-BIM : [8.76670057]
# SNR WAVE-FGSM: [8.71086954]
# Files read: 5900
# SNR WAVE-MF: [24.91535896]
# SNR MF-BIM : [51.27258925]
# SNR MF-FGSM: [46.21763497]
# SNR WAVE-BIM : [25.31863886]
# SNR WAVE-FGSM: [25.65083489]
# Files read: 5950
# SNR WAVE-MF: [12.43092696]
# SNR MF-BIM : [49.96132955]
# SNR MF-FGSM: [42.44226195]
# SNR WAVE-BIM : [12.51920781]
# SNR WAVE-FGSM: [12.64222056]
# Files read: 6000
# SNR WAVE-MF: [9.53662715]
# SNR MF-BIM : [39.30639]
# SNR MF-FGSM: [37.79608385]
# SNR WAVE-BIM : [9.16841379]
# SNR WAVE-FGSM: [9.10021511]
# Files read: 6050
# SNR WAVE-MF: [10.10852367]
# SNR MF-BIM : [37.85787241]
# SNR MF-FGSM: [38.02222968]
# SNR WAVE-BIM : [9.65358044]
# SNR WAVE-FGSM: [9.66189259]
# Files read: 6100
# SNR WAVE-MF: [16.49417431]
# SNR MF-BIM : [39.92880682]
# SNR MF-FGSM: [38.48904183]
# SNR WAVE-BIM : [17.00630766]
# SNR WAVE-FGSM: [17.10194036]
# Files read: 6150
# SNR WAVE-MF: [-1.71842538]
# SNR MF-BIM : [39.63425865]
# SNR MF-FGSM: [44.26989812]
# SNR WAVE-BIM : [-1.88180625]
# SNR WAVE-FGSM: [-1.81460949]
# Files read: 6200
# SNR WAVE-MF: [14.0716315]
# SNR MF-BIM : [41.4610473]
# SNR MF-FGSM: [43.10978626]
# SNR WAVE-BIM : [14.37441087]
# SNR WAVE-FGSM: [14.32130283]
# Files read: 6250
# SNR WAVE-MF: [7.93487104]
# SNR MF-BIM : [38.67420094]
# SNR MF-FGSM: [35.28781501]
# SNR WAVE-BIM : [8.08727779]
# SNR WAVE-FGSM: [8.16089645]
# Files read: 6300
# SNR WAVE-MF: [10.14414354]
# SNR MF-BIM : [36.35149288]
# SNR MF-FGSM: [35.95720971]
# SNR WAVE-BIM : [9.60403077]
# SNR WAVE-FGSM: [9.57974608]
# Files read: 6350
# SNR WAVE-MF: [17.78973185]
# SNR MF-BIM : [39.2781751]
# SNR MF-FGSM: [45.41278494]
# SNR WAVE-BIM : [17.00051289]
# SNR WAVE-FGSM: [17.39130542]
# Files read: 6400
# SNR WAVE-MF: [24.08917622]
# SNR MF-BIM : [32.47922719]
# SNR MF-FGSM: [33.46877498]
# SNR WAVE-BIM : [21.13938676]
# SNR WAVE-FGSM: [21.41295852]
# Files read: 6450
# SNR WAVE-MF: [28.26527669]
# SNR MF-BIM : [36.80165007]
# SNR MF-FGSM: [36.32022459]
# SNR WAVE-BIM : [25.41299242]
# SNR WAVE-FGSM: [25.27552492]
# Files read: 6500
# SNR WAVE-MF: [4.26187221]
# SNR MF-BIM : [31.8138931]
# SNR MF-FGSM: [32.66429448]
# SNR WAVE-BIM : [3.69385774]
# SNR WAVE-FGSM: [3.74529108]
# Files read: 6550
# SNR WAVE-MF: [9.62260675]
# SNR MF-BIM : [46.45153622]
# SNR MF-FGSM: [39.62720896]
# SNR WAVE-BIM : [9.45772252]
# SNR WAVE-FGSM: [9.26488093]
# Files read: 6600
# SNR WAVE-MF: [4.95080391]
# SNR MF-BIM : [43.9219214]
# SNR MF-FGSM: [44.28199412]
# SNR WAVE-BIM : [5.10524994]
# SNR WAVE-FGSM: [5.0989245]
# Files read: 6650
# SNR WAVE-MF: [7.13881131]
# SNR MF-BIM : [41.41401927]
# SNR MF-FGSM: [36.57476479]
# SNR WAVE-BIM : [7.38394913]
# SNR WAVE-FGSM: [6.72679178]
# Files read: 6700
# SNR WAVE-MF: [15.84008222]
# SNR MF-BIM : [50.58600901]
# SNR MF-FGSM: [63.83205409]
# SNR WAVE-BIM : [15.70772673]
# SNR WAVE-FGSM: [15.8111069]
# Files read: 6750
# SNR WAVE-MF: [-7.01204607]
# SNR MF-BIM : [44.09882395]
# SNR MF-FGSM: [47.59010724]
# SNR WAVE-BIM : [-7.0900487]
# SNR WAVE-FGSM: [-7.06430848]
# Files read: 6800
# SNR WAVE-MF: [19.34343083]
# SNR MF-BIM : [48.8809418]
# SNR MF-FGSM: [58.23593146]
# SNR WAVE-BIM : [19.08875185]
# SNR WAVE-FGSM: [19.25584484]
# Files read: 6850
# SNR WAVE-MF: [7.92484056]
# SNR MF-BIM : [38.58572979]
# SNR MF-FGSM: [38.3991956]
# SNR WAVE-BIM : [8.07852213]
# SNR WAVE-FGSM: [8.08188856]
# Files read: 6900
# SNR WAVE-MF: [14.36600801]
# SNR MF-BIM : [33.02109354]
# SNR MF-FGSM: [33.46183769]
# SNR WAVE-BIM : [13.23492418]
# SNR WAVE-FGSM: [13.28755496]

# %%
# SNR WAVE/MF

print("Fold: " + str(test_fold[0]))
print("Mean SNR: " + str(np.mean(snr_wave_mf)))
print("Stnd dev: " + str(np.std(snr_wave_mf)))
# Out:
# Fold: 3
# Mean SNR: 8.420988704047799
# Stnd dev: 11.242556100784293

# %%
# SNR MF/BIM

print("Fold: " + str(test_fold[0]))
print("Mean SNR: " + str(np.mean(snr_mf_bim)))
print("Stnd dev: " + str(np.std(snr_mf_bim)))
# Out:
# Fold: 3
# Mean SNR: 44.47626363974939
# Stnd dev: 9.634049154741913

# %%
# SNR MF/FGSM

print("Fold: " + str(test_fold[0]))
print("Mean SNR: " + str(np.mean(snr_mf_fgsm)))
print("Stnd dev: " + str(np.std(snr_mf_fgsm)))
# Out:
# Fold: 3
# Mean SNR: 43.046974037856955
# Stnd dev: 9.157862517892855

# %%
# SNR WAVE/BIM

print("Fold: " + str(test_fold[0]))
print("Mean SNR: " + str(np.mean(snr_wave_bim)))
print("Stnd dev: " + str(np.std(snr_wave_bim)))
# Out:
# Fold: 3
# Mean SNR: 8.365710494981252
# Stnd dev: 11.219738212407641

# %%
# SNR WAVE/FGSM

print("Fold: " + str(test_fold[0]))
print("Mean SNR: " + str(np.mean(snr_wave_fgsm)))
print("Stnd dev: " + str(np.std(snr_wave_fgsm)))
# Out:
# Fold: 3
# Mean SNR: 8.354530837127609
# Stnd dev: 11.288328700484334

# %%
#Play sound from original reconstructed signal

IPython.display.Audio(data=audio_rec_original, rate=sr)

# %%
#Play sound from attacked reconstructed signal

IPython.display.Audio(data=audio_rec_attacked_bim, rate=sr)

# %%
#Difference

IPython.display.Audio(data=audio_rec_original-audio_rec_attacked_bim, rate=sr)
